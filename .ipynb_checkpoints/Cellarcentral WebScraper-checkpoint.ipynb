# %% [markdown]
# # Cellarcentral Website Scraper Project (BeautifulSoup)
# ### About Cellarcentra Website
#
# At Cellar Central, our mission is to provide logistics solutions that deliver the best shopping experience one customer at a time. We are the leading retail distributor of premium wines and spirits in Nigeria. Our order channels include phone, email, social media and website. We deliver directly to customers’ doorstep and our reach covers major Nigerian cities including Lagos, Port Harcourt, Onitsha, Aba, Abuja and Benin.
#
# **Store Location**
#
# 45 Rasaq Balogun Street, Surulere, Lagos
#
# Phone: 0807 806 1111,  0906 415 6296
#
# Email: info@cellarcentral.ng
#
# **Opening Times**
#
# Mondays to Fridays
# 8 AM - 5 PM
#
# Saturdays
# 9 AM - 1 PM
#
# **Payment Methods**
# We support payments with debit/credit cards (powered by Paystack). We also accept bank transfers to our specified bank account. Orders are shipped on confirmation of payment.
#
# visit site for more information here: https://www.cellarcentral.ng/
#
# ### Five product categories to scrape and their info
# ##### 1. Cellarcentral Wine Products
# Wines are alcoholic beverages that are gotten from fermented grape juice. At Cellar Central; they have a wide range of wines: red, white, rose, sparkling etc. from different parts of the world.
#
# ##### 2. Cellarcentral Spirit Products
# Spirits are alcoholic beverages which are distilled rather than fermented like in wines. spirits category include rum, whisky, cognac, aperitifs & so on.
#
# ##### 3. Cellarcentral Champagne and Sparkling Products
# Champagne are sparkling wines that are made in a region in France called Champagne; these are the very bubbly wines. Champagne is a type of sparkling wine with plenty lively bubbles. Sparkling wines are also bubbling wines but are not as lively as that of champagne.
#
# ##### 4. Cellarcentral Hampers Products
# HAMPERS : Buy premium quality hampers and gift packs for the Christmas, New year, Valentine's Day, Anniversaries, Mother's Day, Father's Day, etc. and have them delivered to your loved ones.
#
# ##### 5. Cellarcentral Gift Ideas Products
# GIFT IDEAS : Get  your ideal Father's Day, Christmas and Birthday gifts for your friends, colleagues and family members this season from our special offers.
#
# **NOTE: All categories has ABV 5.5 and greater with the alcoholic beverages**
#
# ### Problem statement
# 1. Scrape products of different categories and their respective informations as product name, price, image, capacity and link.
# 2. Combine Cellarcentral Wine Products, Cellarcentra Spirit Products, Cellarcentral Champagne and Sparkling Products and Cellarcentral Gift Ideas Products into one DataFrame.

# %% [markdown]
# ##### Importing necessary labraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Scraping all Products
#
# ### Scraping Cellarcentral Wine Product List

# %%
CellarCentra_wine_list = []

# step 1: Pagination: that is navigating through multiple pages
for i in range (1, 5):
    headers = headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}

    # requesting for url. In our case the status code is 200
    permission = requests.get(f'https://www.cellarcentral.ng/wines?page={i}', headers =  headers)

    # passing the html file with beautifulSoup in other to get it in a more redeable and accessible form
    soup = BeautifulSoup(permission.content, 'html.parser')

# step 2:
# saving all html tags that contains all product listings
    all_CellarCentra_wine_products = soup.find_all('div', class_ = 'product-thumb')

    # looping through the above tag to scrape info about each product
    for product in all_CellarCentra_wine_products:
        product_name = product.find('div', class_ = 'caption').a.text.strip().split('*')[0]
        product_price = product.find('div', class_ = 'caption').p.text.strip()
        product_link = product.find('div', class_ = 'image').a['href']
        
        # getting image link for each product
        image_tags = product.find_all('div', class_ = 'image')
        for image in image_tags:
            image = image.find('img', class_ = 'img-fluid')
            image['src']
        product_image = image['src']
        
        # trying a particular info about a product so that if not found set it as null value        
        try:
            product_vol = product.find('div', class_ = 'caption').a.text.strip().split('*')[1]
        except:
            product_vol =  np.NaN

# saving all product listings in pandas dictionary
        CellarCentra_wine_products = {
                        'wine_name' : product_name,
                        'wine_price' : product_price,
                        'wine_vol' : product_vol,
                        'wine_image' : product_image,
                        'wine_product_link' : product_link
                          }

# appending into the list created above in this block all product listings saved in the dictionary 
        CellarCentra_wine_list.append(CellarCentra_wine_products)
        #print('Wine Product Info Saving :' , CellarCentra_wine_products['wine_name'])
  
 #step 3: output

df_wine = pd.DataFrame(CellarCentra_wine_list)
df_wine.to_csv('CellarCentra wine data.csv', index = False)
# Out:
#                                           wine_name  wine_price  \
# 0                  B&G Cuvee Reserve Speciale Rose    ₦3,900.00
# 1                           B&G Reserve Chardonnay    ₦5,200.00
# 2                  Boekenhoutskloof Semillon White   ₦13,000.00
# 3                                 Cheval Des Andes   ₦56,100.00
# 4                        Clarendelle Bordeaux Rose    ₦8,200.00
# 5                           Clarendelle Amber Wine   ₦15,600.00
# 6               Clarendelle Bordeaux Blanc (White)    ₦4,100.00
# 7               Clarendelle Bordeaux Blanc (White)    ₦8,800.00
# 8                 Clarendelle Bordeaux Rouge (Red)    ₦8,700.00
# 9                                Clarendelle Medoc    ₦9,240.00
# 10                       Clarendelle Saint Emilion   ₦10,300.00
# 11                      Cloudy Bay Sauvignon Blanc   ₦20,100.00
# 12                     Conti Buneis Moscato D'Asti    ₦4,900.00
# 13                 Copenhagen Sparkling Tea Lysrod   ₦15,000.00
# 14                      Fortant Cabernet Sauvignon    ₦3,000.00
# 15                         Fortant Sauvignon Blanc    ₦3,000.00
# 16                    Gerard Bertrand 6 Sens Blanc    ₦4,900.00
# 17                    Gerard Bertrand 6 Sens Rouge    ₦3,800.00
# 18          Gerard Bertrand Art De Vivre Clairette    ₦8,500.00
# 19               Gerard Bertrand Art de Vivre Rose    ₦7,400.00
# 20              Gerard Bertrand Art de Vivre Rouge    ₦8,200.00
# 21                     Gerard Bertrand Cigalus Red   ₦40,700.00
# 22       Gerard Bertrand Cote des Roses Chardonnay    ₦6,200.00
# 23             Gerard Bertrand Cote des Roses Rose    ₦6,200.00
# 24  Gerard Bertrand Cote des Roses Sauvignon Blanc    ₦6,200.00
# 25              Haute Couture French Bubbles Blanc    ₦9,900.00
# 26               Haute Couture French Bubbles Rose    ₦9,900.00
# 27               Krone Borealis Vintage Cuvee Brut    ₦6,000.00
# 28               Krone Sparkling Night Nectar Rose    ₦6,400.00
# 29           Maison Castel Cabernet Sauvignon 2020    ₦2,800.00
# 30              Maison Castel Sauvignon Blanc 2020    ₦4,800.00
# 31                     MARTINI Asti Sparkling Wine    ₦5,400.00
# 32                                Martini Prosecco    ₦5,600.00
# 33                                    Martini Rose    ₦5,400.00
# 34                                  MARTINI ® Brut    ₦5,800.00
# 35                    Pascal Jolivet Sancerre 2020   ₦16,000.00
# 36                        Penfolds St Henri Shiraz   ₦35,800.00
# 37                     Robertson Winery Chapel Red    ₦4,000.00
# 38               Robertson Winery Chapel Sweet Red    ₦4,000.00
# 39                   Robertson Winery Chapel White    ₦4,000.00
# 40              Robertson Winery Natural Sweet Red    ₦4,300.00
# 41             Robertson Winery Natural Sweet Rose    ₦4,300.00
# 42            Robertson Winery Natural Sweet White    ₦4,300.00
# 43                          Roche Mazet Chardonnay    ₦4,400.00
# 44                           Roche Mazet Sauvignon    ₦2,400.00
# 45                            Sandeman White Porto    ₦6,000.00
# 46                           Santa Cristina Umbria    ₦7,800.00
# 47                                    Scavi and Ray   ₦6,500.00
# 48                   Sweet Lips Natural Sweet Rose    ₦3,500.00
# 49                  Sweet Lips Natural Sweet White    ₦3,500.00
# 50                             Terrazas Chardonnay    ₦8,500.00
# 51                         Terrazas Reserva Malbec    ₦9,600.00
# 52                      Terrazas Reserva Torrontes    ₦8,500.00
# 53                             The Chocolate Block   ₦14,000.00
# 54              Thomas Barton Reserve Graves Blanc    ₦4,600.00
# 55                              Tignanello Toscana   ₦90,200.00
# 56                      Whispering Angel Rose Wine   ₦12,700.00
#
#             wine_vol                                         wine_image  \
# 0               75cl  https://www.cellarcentral.ng/image/cache/catal...
# 1               75CL  https://www.cellarcentral.ng/image/cache/catal...
# 2               75cl  https://www.cellarcentral.ng/image/cache/catal...
# 3               75cl  https://www.cellarcentral.ng/image/cache/catal...
# 4               75cl  https://www.cellarcentral.ng/image/cache/catal...
# 5               50cl  https://www.cellarcentral.ng/image/cache/catal...
# 6             37.5CL  https://www.cellarcentral.ng/image/cache/catal...
# 7               75CL  https://www.cellarcentral.ng/image/cache/catal...
# 8               75CL  https://www.cellarcentral.ng/image/cache/catal...
# 9               75CL  https://www.cellarcentral.ng/image/cache/catal...
# 10              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 11              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 12              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 13              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 14              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 15              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 16              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 17              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 18              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 19              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 20              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 21  75cl (2 Bottles)  https://www.cellarcentral.ng/image/cache/catal...
# 22              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 23              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 24              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 25              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 26              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 27              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 28              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 29              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 30              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 31              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 32              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 33              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 34              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 35              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 36              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 37              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 38              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 39              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 40              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 41              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 42              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 43              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 44              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 45              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 46              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 47               NaN  https://www.cellarcentral.ng/image/cache/catal...
# 48              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 49              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 50              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 51              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 52              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 53              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 54              75CL  https://www.cellarcentral.ng/image/cache/catal...
# 55              75cl  https://www.cellarcentral.ng/image/cache/catal...
# 56              75cl  https://www.cellarcentral.ng/image/cache/catal...
#
#                                     wine_product_link
# 0   https://www.cellarcentral.ng/wines?product_id=704
# 1   https://www.cellarcentral.ng/wines/b-and-g-res...
# 2   https://www.cellarcentral.ng/wines?product_id=563
# 3   https://www.cellarcentral.ng/wines?product_id=495
# 4   https://www.cellarcentral.ng/wines/clarendelle...
# 5   https://www.cellarcentral.ng/wines?product_id=607
# 6   https://www.cellarcentral.ng/wines?product_id=703
# 7   https://www.cellarcentral.ng/wines?product_id=557
# 8   https://www.cellarcentral.ng/wines?product_id=556
# 9   https://www.cellarcentral.ng/wines?product_id=923
# 10  https://www.cellarcentral.ng/wines?product_id=558
# 11  https://www.cellarcentral.ng/wines?product_id=518
# 12  https://www.cellarcentral.ng/wines?product_id=785
# 13  https://www.cellarcentral.ng/wines?product_id=926
# 14  https://www.cellarcentral.ng/wines?product_id=591
# 15  https://www.cellarcentral.ng/wines?product_id=592
# 16  https://www.cellarcentral.ng/wines?product_id=600
# 17  https://www.cellarcentral.ng/wines?product_id=599
# 18  https://www.cellarcentral.ng/wines?product_id=608
# 19  https://www.cellarcentral.ng/wines?product_id=783
# 20  https://www.cellarcentral.ng/wines?product_id=609
# 21  https://www.cellarcentral.ng/wines?product_id=882
# 22  https://www.cellarcentral.ng/wines?product_id=545
# 23  https://www.cellarcentral.ng/wines?product_id=526
# 24  https://www.cellarcentral.ng/wines?product_id=611
# 25  https://www.cellarcentral.ng/wines?product_id=492
# 26  https://www.cellarcentral.ng/wines?product_id=491
# 27  https://www.cellarcentral.ng/wines?product_id=581
# 28  https://www.cellarcentral.ng/wines?product_id=512
# 29  https://www.cellarcentral.ng/wines?product_id=814
# 30  https://www.cellarcentral.ng/wines?product_id=886
# 31    https://www.cellarcentral.ng/wines/martini-asti
# 32  https://www.cellarcentral.ng/wines/martini-pro...
# 33    https://www.cellarcentral.ng/wines/martini-rose
# 34    https://www.cellarcentral.ng/wines/martini-brut
# 35  https://www.cellarcentral.ng/wines?product_id=924
# 36  https://www.cellarcentral.ng/wines?product_id=441
# 37  https://www.cellarcentral.ng/wines?product_id=399
# 38  https://www.cellarcentral.ng/wines?product_id=505
# 39  https://www.cellarcentral.ng/wines?product_id=493
# 40  https://www.cellarcentral.ng/wines?product_id=748
# 41  https://www.cellarcentral.ng/wines?product_id=749
# 42  https://www.cellarcentral.ng/wines?product_id=750
# 43  https://www.cellarcentral.ng/wines?product_id=916
# 44  https://www.cellarcentral.ng/wines?product_id=836
# 45  https://www.cellarcentral.ng/wines/sandeman-wh...
# 46  https://www.cellarcentral.ng/wines?product_id=727
# 47  https://www.cellarcentral.ng/wines?product_id=701
# 48  https://www.cellarcentral.ng/wines?product_id=804
# 49  https://www.cellarcentral.ng/wines?product_id=805
# 50  https://www.cellarcentral.ng/wines?product_id=445
# 51  https://www.cellarcentral.ng/wines?product_id=414
# 52  https://www.cellarcentral.ng/wines?product_id=415
# 53  https://www.cellarcentral.ng/wines/the-chocola...
# 54  https://www.cellarcentral.ng/wines/thomas-bart...
# 55  https://www.cellarcentral.ng/wines?product_id=800
# 56  https://www.cellarcentral.ng/wines?product_id=546

# %% [markdown]
# ### Scraping Cellarcentral Spirit Product List

# %%
CellarCentra_spirit_list = []

# step 1
for j in range (1, 8):
    headers = headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}
    permission = requests.get(f'https://www.cellarcentral.ng/spirits?page={j}', headers =  headers)
    soup = BeautifulSoup(permission.content, 'html.parser')

# step 2    
    all_CellarCentra_spirit_products = soup.find_all('div', class_ = 'product-thumb')

    for product in all_CellarCentra_spirit_products:
        product_name = product.find('div', class_ = 'caption').a.text.strip().split('*')[0]
        product_price = product.find('div', class_ = 'caption').p.text.strip()
        product_link = product.find('div', class_ = 'image').a['href']
        
        # getting image link for each product
        image_tags = product.find_all('div', class_ = 'image')
        for image in image_tags:
            image = image.find('img', class_ = 'img-fluid')
            image['src']
        product_image = image['src']
        
        try:
            product_vol = product.find('div', class_ = 'caption').a.text.strip().split('*')[1]
        except:
            product_vol = np.NaN

        CellarCentra_spirit_products = {
                        'spirit_name' : product_name,
                        'spirit_price' : product_price,
                        'spirit_vol' : product_vol,
                        'spirit_image' : product_image,
                        'spirit_product_link' : product_link
                          }

        CellarCentra_spirit_list.append(CellarCentra_spirit_products)
        #print('spirit Product Info Saving :' , CellarCentra_spirit_products['spirit_name'])

    
# step 3: output
df_spirit = pd.DataFrame(CellarCentra_spirit_list)
df_spirit.to_csv('CellarCentra spirit data.csv', index = False)
# Out:
#                          spirit_name spirit_price spirit_vol  \
# 0                   Absolut Vanilia     ₦6,000.00         1L
# 1                Amaro Di Angostura     ₦7,700.00       70CL
# 2                    American Honey     ₦9,600.00       75CL
# 3                    Angostura 1787    ₦33,600.00       70CL
# 4          Angostura 1824 12yrs Old    ₦29,600.00       70CL
# ..                               ...          ...        ...
# 94       The Nubi Aphro Palm Spirit    ₦24,000.00       75CL
# 95  The Observatory Whisky 20 years    ₦20,150.00       70cl
# 96                    Volcan Blanco    ₦32,600.00       70CL
# 97               Volcan Cristallino    ₦53,000.00       75cl
# 98   WILLIAM LAWSON'S™ Finest Blend     ₦5,300.00       75cl
#
#                                          spirit_image  \
# 0   https://www.cellarcentral.ng/image/cache/catal...
# 1   https://www.cellarcentral.ng/image/cache/catal...
# 2   https://www.cellarcentral.ng/image/cache/catal...
# 3   https://www.cellarcentral.ng/image/cache/catal...
# 4   https://www.cellarcentral.ng/image/cache/catal...
# ..                                                ...
# 94  https://www.cellarcentral.ng/image/cache/catal...
# 95  https://www.cellarcentral.ng/image/cache/catal...
# 96  https://www.cellarcentral.ng/image/cache/catal...
# 97  https://www.cellarcentral.ng/image/cache/catal...
# 98  https://www.cellarcentral.ng/image/cache/catal...
#
#                                   spirit_product_link
# 0   https://www.cellarcentral.ng/spirits?product_i...
# 1   https://www.cellarcentral.ng/spirits?product_i...
# 2   https://www.cellarcentral.ng/spirits/american-...
# 3   https://www.cellarcentral.ng/spirits?product_i...
# 4   https://www.cellarcentral.ng/spirits?product_i...
# ..                                                ...
# 94  https://www.cellarcentral.ng/spirits?product_i...
# 95  https://www.cellarcentral.ng/spirits?product_i...
# 96  https://www.cellarcentral.ng/spirits?product_i...
# 97  https://www.cellarcentral.ng/spirits?product_i...
# 98  https://www.cellarcentral.ng/spirits?product_i...
#
# [99 rows x 5 columns]

# %% [markdown]
# ### Scraping Cellarcentral Champagne Product List

# %%
CellarCentra_Champagne_list = []

# step 1
for x in range (1, 4):
    headers = headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}
    permission = requests.get(f'https://www.cellarcentral.ng/champagne-and-sparkling?page={x}', headers =  headers)
    soup = BeautifulSoup(permission.content, 'html.parser')

# step 2
    all_CellarCentra_Champagne_products = soup.find_all('div', class_ = 'product-thumb')

    for product in all_CellarCentra_Champagne_products:
        product_name = product.find('div', class_ = 'caption').a.text.strip().split('*')[0]
        product_price = product.find('div', class_ = 'caption').p.text.strip()
        product_link = product.find('div', class_ = 'image').a['href']
        
        # getting image link for each product
        image_tags = product.find_all('div', class_ = 'image')
        for image in image_tags:
            image = image.find('img', class_ = 'img-fluid')
            image['src']
        product_image = image['src']
        
        try:
            product_vol = product.find('div', class_ = 'caption').a.text.strip().split('*')[1]
        except:
            product_vol = np.NaN

        CellarCentra_Champagne_products = {
                        'Champagne_name' : product_name,
                        'Champagne_price' : product_price,
                        'Champagne_vol' : product_vol,
                        'Champagne_image' : product_image,
                         'Champagne_product_link' : product_link
                          }

        CellarCentra_Champagne_list.append(CellarCentra_Champagne_products)
        #print('Champagne Product Info Saving :' , CellarCentra_Champagne_products['Champagne_name'])

    
# step 3: output
df_champagne = pd.DataFrame(CellarCentra_Champagne_list)
df_champagne.to_csv('CellarCentra champagne data.csv', index = False)
# Out:
#                                      Champagne_name Champagne_price  \
# 0                      Armand de Brignac Brut Gold      ₦255,200.00
# 1                           Armand de Brignac Rosé      ₦359,600.00
# 2                       Billecart Salmon Brut Rose       ₦58,500.00
# 3                        Billecart Salmon Demi-sec       ₦41,400.00
# 4                                   Bollinger Rosé       ₦45,000.00
# 5                     Bollinger Special Cuvée Brut       ₦30,500.00
# 6                      Conti Buneis Moscato D'Asti        ₦4,900.00
# 7               Haute Couture French Bubbles Blanc        ₦9,900.00
# 8                Krone Borealis Vintage Cuvee Brut        ₦6,000.00
# 9                       Laurent Perrier Cuvee Rose       ₦52,000.00
# 10       Laurent Perrier Cuvee Rose Butterfly Cage       ₦60,200.00
# 11                Laurent Perrier Harmony Demi-Sec       ₦37,000.00
# 12                   Laurent Perrier La Cuvee Brut       ₦35,000.00
# 13  Maison Castel Ice Cuvee Blanche Demi Sec White        ₦3,400.00
# 14     Maison Castel Ice Cuvee Rosee Demi Sec Rose        ₦3,400.00
# 15                                    Martini Rose        ₦5,400.00
# 16                    Moet & Chandon Brut Imperial       ₦51,040.00
# 17       Moet & Chandon Brut Imperial Love Edition       ₦45,900.00
# 18                     Moet & Chandon Ice Imperial       ₦65,500.00
# 19                  Moet & Chandon Nectar Imperial       ₦50,400.00
# 20             Moet & Chandon Nectar Rose Imperial       ₦55,000.00
# 21                    Moet & Chandon Rose Imperial       ₦55,800.00
# 22       Moet & Chandon Rose Imperial Love Edition       ₦48,100.00
# 23       Nicolas Feuillatte Reserve Exclusive Brut       ₦34,300.00
# 24       Nicolas Feuillatte Reserve Exclusive Rose       ₦40,450.00
# 25  Nicolas Feuillatte Reserve Exclusive Rose Mini       ₦22,530.00
# 26                   Palmes D’or 2008 Intense Brut      ₦100,000.00
# 27                   Palmes D’or 2008 Intense Rose      ₦124,800.00
# 28      Rich Lady Sparkling Rose Demi-sec (Sleeve)        ₦3,000.00
# 29                    Rich Lady Sparkling Rose Wine       ₦2,600.00
# 30                          Ruinart Champagne Brut       ₦39,700.00
# 31                             Veuve Clicquot Brut       ₦50,420.00
# 32                             Veuve Clicquot Rich       ₦74,900.00
# 33                             Veuve Clicquot Rose       ₦51,700.00
#
#           Champagne_vol                                    Champagne_image  \
# 0   75cl (Ace of Spade)  https://www.cellarcentral.ng/image/cache/catal...
# 1   75cl (Ace of Spade)  https://www.cellarcentral.ng/image/cache/catal...
# 2                  75CL  https://www.cellarcentral.ng/image/cache/catal...
# 3                  75CL  https://www.cellarcentral.ng/image/cache/catal...
# 4                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 5                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 6                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 7                  75CL  https://www.cellarcentral.ng/image/cache/catal...
# 8                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 9                  75CL  https://www.cellarcentral.ng/image/cache/catal...
# 10                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 11                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 12                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 13                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 14                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 15                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 16                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 17                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 18                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 19                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 20                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 21                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 22                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 23                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 24                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 25               37.5cl  https://www.cellarcentral.ng/image/cache/catal...
# 26                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 27                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 28                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 29                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 30                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 31                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 32                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 33                 75CL  https://www.cellarcentral.ng/image/cache/catal...
#
#                                Champagne_product_link
# 0   https://www.cellarcentral.ng/champagne-and-spa...
# 1   https://www.cellarcentral.ng/champagne-and-spa...
# 2   https://www.cellarcentral.ng/champagne-and-spa...
# 3   https://www.cellarcentral.ng/champagne-and-spa...
# 4   https://www.cellarcentral.ng/champagne-and-spa...
# 5   https://www.cellarcentral.ng/champagne-and-spa...
# 6   https://www.cellarcentral.ng/champagne-and-spa...
# 7   https://www.cellarcentral.ng/champagne-and-spa...
# 8   https://www.cellarcentral.ng/champagne-and-spa...
# 9   https://www.cellarcentral.ng/champagne-and-spa...
# 10  https://www.cellarcentral.ng/champagne-and-spa...
# 11  https://www.cellarcentral.ng/champagne-and-spa...
# 12  https://www.cellarcentral.ng/champagne-and-spa...
# 13  https://www.cellarcentral.ng/champagne-and-spa...
# 14  https://www.cellarcentral.ng/champagne-and-spa...
# 15  https://www.cellarcentral.ng/champagne-and-spa...
# 16  https://www.cellarcentral.ng/champagne-and-spa...
# 17  https://www.cellarcentral.ng/champagne-and-spa...
# 18  https://www.cellarcentral.ng/champagne-and-spa...
# 19  https://www.cellarcentral.ng/champagne-and-spa...
# 20  https://www.cellarcentral.ng/champagne-and-spa...
# 21  https://www.cellarcentral.ng/champagne-and-spa...
# 22  https://www.cellarcentral.ng/champagne-and-spa...
# 23  https://www.cellarcentral.ng/champagne-and-spa...
# 24  https://www.cellarcentral.ng/champagne-and-spa...
# 25  https://www.cellarcentral.ng/champagne-and-spa...
# 26  https://www.cellarcentral.ng/champagne-and-spa...
# 27  https://www.cellarcentral.ng/champagne-and-spa...
# 28  https://www.cellarcentral.ng/champagne-and-spa...
# 29  https://www.cellarcentral.ng/champagne-and-spa...
# 30  https://www.cellarcentral.ng/champagne-and-spa...
# 31  https://www.cellarcentral.ng/champagne-and-spa...
# 32  https://www.cellarcentral.ng/champagne-and-spa...
# 33  https://www.cellarcentral.ng/champagne-and-spa...

# %% [markdown]
# ### Scraping Cellarcentral Gift Ideas Product List

# %%
CellarCentra_gift_ideas_list = []

# step 1
for y in range (1, 4):
    headers = headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}
    permission = requests.get(f'https://www.cellarcentral.ng/special-offers?page={y}', headers =  headers)
    soup = BeautifulSoup(permission.content, 'html.parser')

# step 2
    all_CellarCentra_gift_ideas_products = soup.find_all('div', class_ = 'product-thumb')

    for product in all_CellarCentra_gift_ideas_products:
        product_name = product.find('div', class_ = 'caption').a.text.strip().split('*')[0]
        product_price = product.find('div', class_ = 'caption').p.text.strip()
        product_link = product.find('div', class_ = 'image').a['href']
        
        # getting image link for each product
        image_tags = product.find_all('div', class_ = 'image')
        for image in image_tags:
            image = image.find('img', class_ = 'img-fluid')
            image['src']
        product_image = image['src']
        
        try:
            product_vol = product.find('div', class_ = 'caption').a.text.strip().split('*')[1]
        except:
            product_vol = np.NaN

        CellarCentra_gift_ideas_products = {
                        'gift_ideas_name' : product_name,
                        'gift_ideas_price' : product_price,
                        'gift_ideas_vol' : product_vol,
                        'gift_ideas_image' : product_image,
                        'gift_ideas_product_link' : product_link
                          }

        CellarCentra_gift_ideas_list.append(CellarCentra_gift_ideas_products)
        #print('gift_ideas Product Info Saving :' , CellarCentra_gift_ideas_products['gift_ideas_name'])

    
# step 3: output
df_gift_ideas = pd.DataFrame(CellarCentra_gift_ideas_list)
df_gift_ideas.to_csv('CellarCentra gift idea data.csv', index = False)
# Out:
#                                gift_ideas_name gift_ideas_price  \
# 0                    Angostura 1824 12yrs Old        ₦29,600.00
# 1                      Armand de Brignac Rosé       ₦359,600.00
# 2                    BARON OTARD® VSOP Cognac        ₦30,700.00
# 3                              Bollinger Rosé        ₦45,000.00
# 4                Bollinger Special Cuvée Brut        ₦30,500.00
# 5                               CC Gold Hamper      ₦300,000.00
# 6                           CC Platinum Hamper      ₦400,000.00
# 7                     CC Silver Festive Hamper      ₦150,000.00
# 8                     Delamain Pale & Dry X.O        ₦49,100.00
# 9     Delamain TRIO Cognac Giftbox (3 x 200ml)       ₦45,500.00
# 10   Fortnum's Time for Tea 3-Minute Tea Timer       ₦15,000.00
# 11                Gerard Bertrand Cigalus Red        ₦40,700.00
# 12                    Gin Etsu Japanese Gin 70       ₦15,400.00
# 13                    Glenfiddich 12 Year Old        ₦23,400.00
# 14                    Glenfiddich 15 Year Old        ₦32,300.00
# 15                    Glenfiddich 18 Year Old        ₦51,000.00
# 16                    Glenfiddich 21 Year Old       ₦141,400.00
# 17                    Glenfiddich 26 Year Old       ₦500,000.00
# 18          Glenfiddich Grand Cru 23 Year Old       ₦269,000.00
# 19                         Glenmorangie 18 YO        ₦68,000.00
# 20               Glenmorangie Signet Gift Box       ₦149,000.00
# 21  Laurent Perrier Cuvee Rose Butterfly Cage        ₦60,200.00
# 22                             LIFVER Coasters       ₦12,000.00
# 23  Moet & Chandon Brut Imperial Love Edition        ₦45,900.00
# 24  Moet & Chandon Rose Imperial Love Edition        ₦48,100.00
# 25                     Mother's Day Gift Set 1       ₦60,000.00
# 26                     Mother's Day Gift Set 2       ₦60,000.00
# 27              Palmes D’or 2008 Intense Brut       ₦100,000.00
# 28              Palmes D’or 2008 Intense Rose       ₦124,800.00
# 29                   Penfolds St Henri Shiraz        ₦35,800.00
# 30                            Sainte Croix XO        ₦76,000.00
# 31               The Macallan Rare Cask Whisky      ₦153,600.00
# 32  The Macallan Triple Cask Matured 12 Years        ₦31,200.00
# 33              Valentine's Gift Set for Her 1      ₦100,000.00
# 34              Valentine's Gift Set for Her 2       ₦60,000.00
# 35              Valentine's Gift Set for Him 1      ₦100,000.00
# 36              Valentine's Gift Set for Him 2       ₦60,000.00
# 37                        Veuve Clicquot Brut        ₦50,420.00
#
#          gift_ideas_vol                                   gift_ideas_image  \
# 0                  70CL  https://www.cellarcentral.ng/image/cache/catal...
# 1   75cl (Ace of Spade)  https://www.cellarcentral.ng/image/cache/catal...
# 2                  70cl  https://www.cellarcentral.ng/image/cache/catal...
# 3                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 4                  75cl  https://www.cellarcentral.ng/image/cache/catal...
# 5                   NaN  https://www.cellarcentral.ng/image/cache/catal...
# 6                   NaN  https://www.cellarcentral.ng/image/cache/catal...
# 7                   NaN  https://www.cellarcentral.ng/image/cache/catal...
# 8                  70CL  https://www.cellarcentral.ng/image/cache/catal...
# 9                   NaN  https://www.cellarcentral.ng/image/cache/catal...
# 10                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 11     75cl (2 Bottles)  https://www.cellarcentral.ng/image/cache/catal...
# 12                   cl  https://www.cellarcentral.ng/image/cache/catal...
# 13                 70CL  https://www.cellarcentral.ng/image/cache/catal...
# 14                 70CL  https://www.cellarcentral.ng/image/cache/catal...
# 15                 70CL  https://www.cellarcentral.ng/image/cache/catal...
# 16                 70CL  https://www.cellarcentral.ng/image/cache/catal...
# 17                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 18                 70CL  https://www.cellarcentral.ng/image/cache/catal...
# 19                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 20                 70cl  https://www.cellarcentral.ng/image/cache/catal...
# 21                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 22                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 23                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 24                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 25                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 26                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 27                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 28                 75cl  https://www.cellarcentral.ng/image/cache/catal...
# 29                 75CL  https://www.cellarcentral.ng/image/cache/catal...
# 30                 70cl  https://www.cellarcentral.ng/image/cache/catal...
# 31                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 32                 70cl  https://www.cellarcentral.ng/image/cache/catal...
# 33                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 34                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 35                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 36                  NaN  https://www.cellarcentral.ng/image/cache/catal...
# 37                 75CL  https://www.cellarcentral.ng/image/cache/catal...
#
#                               gift_ideas_product_link
# 0   https://www.cellarcentral.ng/special-offers?pr...
# 1   https://www.cellarcentral.ng/special-offers?pr...
# 2   https://www.cellarcentral.ng/special-offers/ba...
# 3   https://www.cellarcentral.ng/special-offers?pr...
# 4   https://www.cellarcentral.ng/special-offers?pr...
# 5   https://www.cellarcentral.ng/special-offers?pr...
# 6   https://www.cellarcentral.ng/special-offers?pr...
# 7   https://www.cellarcentral.ng/special-offers?pr...
# 8   https://www.cellarcentral.ng/special-offers/de...
# 9   https://www.cellarcentral.ng/special-offers?pr...
# 10  https://www.cellarcentral.ng/special-offers?pr...
# 11  https://www.cellarcentral.ng/special-offers?pr...
# 12  https://www.cellarcentral.ng/special-offers?pr...
# 13  https://www.cellarcentral.ng/special-offers/gl...
# 14  https://www.cellarcentral.ng/special-offers/gl...
# 15  https://www.cellarcentral.ng/special-offers/gl...
# 16  https://www.cellarcentral.ng/special-offers?pr...
# 17  https://www.cellarcentral.ng/special-offers?pr...
# 18  https://www.cellarcentral.ng/special-offers?pr...
# 19  https://www.cellarcentral.ng/special-offers/gl...
# 20  https://www.cellarcentral.ng/special-offers?pr...
# 21  https://www.cellarcentral.ng/special-offers?pr...
# 22  https://www.cellarcentral.ng/special-offers?pr...
# 23  https://www.cellarcentral.ng/special-offers/mo...
# 24  https://www.cellarcentral.ng/special-offers?pr...
# 25  https://www.cellarcentral.ng/special-offers?pr...
# 26  https://www.cellarcentral.ng/special-offers?pr...
# 27  https://www.cellarcentral.ng/special-offers?pr...
# 28  https://www.cellarcentral.ng/special-offers?pr...
# 29  https://www.cellarcentral.ng/special-offers?pr...
# 30  https://www.cellarcentral.ng/special-offers?pr...
# 31  https://www.cellarcentral.ng/special-offers/ma...
# 32  https://www.cellarcentral.ng/special-offers?pr...
# 33  https://www.cellarcentral.ng/special-offers?pr...
# 34  https://www.cellarcentral.ng/special-offers?pr...
# 35  https://www.cellarcentral.ng/special-offers?pr...
# 36  https://www.cellarcentral.ng/special-offers?pr...
# 37  https://www.cellarcentral.ng/special-offers/ve...

# %% [markdown]
# ### Scraping Cellarcentral hampers Product List

# %%
CellarCentra_hampers_list = []

# step 1
headers = headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'}
permission = requests.get('https://www.cellarcentral.ng/hampers', headers =  headers)
soup = BeautifulSoup(permission.content, 'html.parser')

# step 2
all_CellarCentra_hampers_products = soup.find_all('div', class_ = 'product-thumb')

for product in all_CellarCentra_hampers_products:
    product_name = product.find('div', class_ = 'caption').a.text.strip()
    product_price = product.find('div', class_ = 'caption').p.text.strip()
    product_link = product.find('div', class_ = 'image').a['href']
    
    # getting image link for each product
    image_tags = product.find_all('div', class_ = 'image')
    for image in image_tags:
        image = image.find('img', class_ = 'img-fluid')
        image['src']
    product_image = image['src']
        
    CellarCentra_hampers_products = {
                        'hampers_name' : product_name,
                        'hampers_price' : product_price,
                        'hampers_image' : product_image,
                        'hampers_product_link' : product_link
                          }

    CellarCentra_hampers_list.append(CellarCentra_hampers_products)
    #print('hampers Product Info Saving :' , CellarCentra_hampers_products['hampers_name'])

    
# step 3: output
df_hampers = pd.DataFrame(CellarCentra_hampers_list)
df_hampers.to_csv('CellarCentra hampers data.csv', index = False)
# Out:
#                      hampers_name hampers_price  \
# 0                  CC Gold Hamper   ₦300,000.00
# 1              CC Platinum Hamper   ₦400,000.00
# 2        CC Silver Festive Hamper   ₦150,000.00
# 3         Mother's Day Gift Set 1    ₦60,000.00
# 4         Mother's Day Gift Set 2    ₦60,000.00
# 5  Valentine's Gift Set for Her 1   ₦100,000.00
# 6  Valentine's Gift Set for Her 2    ₦60,000.00
# 7  Valentine's Gift Set for Him 1   ₦100,000.00
# 8  Valentine's Gift Set for Him 2    ₦60,000.00
#
#                                        hampers_image  \
# 0  https://www.cellarcentral.ng/image/cache/catal...
# 1  https://www.cellarcentral.ng/image/cache/catal...
# 2  https://www.cellarcentral.ng/image/cache/catal...
# 3  https://www.cellarcentral.ng/image/cache/catal...
# 4  https://www.cellarcentral.ng/image/cache/catal...
# 5  https://www.cellarcentral.ng/image/cache/catal...
# 6  https://www.cellarcentral.ng/image/cache/catal...
# 7  https://www.cellarcentral.ng/image/cache/catal...
# 8  https://www.cellarcentral.ng/image/cache/catal...
#
#                                 hampers_product_link
# 0  https://www.cellarcentral.ng/hampers?product_i...
# 1  https://www.cellarcentral.ng/hampers?product_i...
# 2  https://www.cellarcentral.ng/hampers?product_i...
# 3  https://www.cellarcentral.ng/hampers?product_i...
# 4  https://www.cellarcentral.ng/hampers?product_i...
# 5  https://www.cellarcentral.ng/hampers?product_i...
# 6  https://www.cellarcentral.ng/hampers?product_i...
# 7  https://www.cellarcentral.ng/hampers?product_i...
# 8  https://www.cellarcentral.ng/hampers?product_i...

# %% [markdown]
# # 2. Combine Cellarcentral all Product
# ### Reading the Scraped Datas into workspace

# %%
df_wine = pd.read_csv('CellarCentra wine data.csv')
df_spirit = pd.read_csv('CellarCentra spirit data.csv')
df_champagne = pd.read_csv('CellarCentra champagne data.csv')
df_gift_idea = pd.read_csv('CellarCentra gift idea data.csv')
df_hampers = pd.read_csv('CellarCentra hampers data.csv')

# %% [markdown]
# ### Accesing the data

# %%
df_wine.head(3)
# Out:
#                           wine_name  wine_price wine_vol  \
# 0  B&G Cuvee Reserve Speciale Rose    ₦3,900.00     75cl
# 1           B&G Reserve Chardonnay    ₦5,200.00     75CL
# 2  Boekenhoutskloof Semillon White   ₦13,000.00     75cl
#
#                                    wine_product_link
# 0  https://www.cellarcentral.ng/wines?product_id=704
# 1  https://www.cellarcentral.ng/wines/b-and-g-res...
# 2  https://www.cellarcentral.ng/wines?product_id=563

# %%
df_spirit.head(3)
# Out:
#            spirit_name spirit_price spirit_vol  \
# 0     Absolut Vanilia     ₦6,000.00         1L
# 1  Amaro Di Angostura     ₦7,700.00       70CL
# 2      American Honey     ₦9,600.00       75CL
#
#                                  spirit_product_link
# 0  https://www.cellarcentral.ng/spirits?product_i...
# 1  https://www.cellarcentral.ng/spirits?product_i...
# 2  https://www.cellarcentral.ng/spirits/american-...

# %%
df_champagne.head(3)
# Out:
#                  Champagne_name Champagne_price        Champagne_vol  \
# 0  Armand de Brignac Brut Gold      ₦255,200.00  75cl (Ace of Spade)
# 1       Armand de Brignac Rosé      ₦359,600.00  75cl (Ace of Spade)
# 2   Billecart Salmon Brut Rose       ₦58,500.00                 75CL
#
#                               Champagne_product_link
# 0  https://www.cellarcentral.ng/champagne-and-spa...
# 1  https://www.cellarcentral.ng/champagne-and-spa...
# 2  https://www.cellarcentral.ng/champagne-and-spa...

# %%
df_gift_idea.head(3)
# Out:
#              gift_ideas_name gift_ideas_price       gift_ideas_vol  \
# 0  Angostura 1824 12yrs Old        ₦29,600.00                 70CL
# 1    Armand de Brignac Rosé       ₦359,600.00  75cl (Ace of Spade)
# 2  BARON OTARD® VSOP Cognac        ₦30,700.00                 70cl
#
#                              gift_ideas_product_link
# 0  https://www.cellarcentral.ng/special-offers?pr...
# 1  https://www.cellarcentral.ng/special-offers?pr...
# 2  https://www.cellarcentral.ng/special-offers/ba...

# %% [markdown]
# ### Add a new column category to each dataframe

# %%
categories = np.repeat('wine', df_wine.shape[0])
df_wine['category'] = categories

categories = np.repeat('spirit', df_spirit.shape[0])
df_spirit['category'] = categories

categories = np.repeat('hampagne', df_champagne.shape[0])
df_champagne['category'] = categories

categories = np.repeat('gift idea', df_gift_idea.shape[0])
df_gift_idea['category'] = categories

df_gift_idea.head(2)
# Out:
#              gift_ideas_name gift_ideas_price       gift_ideas_vol  \
# 0  Angostura 1824 12yrs Old        ₦29,600.00                 70CL
# 1    Armand de Brignac Rosé       ₦359,600.00  75cl (Ace of Spade)
#
#                              gift_ideas_product_link   category
# 0  https://www.cellarcentral.ng/special-offers?pr...  gift idea
# 1  https://www.cellarcentral.ng/special-offers?pr...  gift idea

# %%
df_wine.head(2)
# Out:
#                           wine_name wine_price wine_vol  \
# 0  B&G Cuvee Reserve Speciale Rose   ₦3,900.00     75cl
# 1           B&G Reserve Chardonnay   ₦5,200.00     75CL
#
#                                    wine_product_link category
# 0  https://www.cellarcentral.ng/wines?product_id=704     wine
# 1  https://www.cellarcentral.ng/wines/b-and-g-res...     wine

# %%
df_spirit.head(2)
# Out:
#            spirit_name spirit_price spirit_vol  \
# 0     Absolut Vanilia     ₦6,000.00         1L
# 1  Amaro Di Angostura     ₦7,700.00       70CL
#
#                                  spirit_product_link category
# 0  https://www.cellarcentral.ng/spirits?product_i...   spirit
# 1  https://www.cellarcentral.ng/spirits?product_i...   spirit

# %%
df_champagne.head(2)
# Out:
#                  Champagne_name Champagne_price        Champagne_vol  \
# 0  Armand de Brignac Brut Gold      ₦255,200.00  75cl (Ace of Spade)
# 1       Armand de Brignac Rosé      ₦359,600.00  75cl (Ace of Spade)
#
#                               Champagne_product_link  category
# 0  https://www.cellarcentral.ng/champagne-and-spa...  hampagne
# 1  https://www.cellarcentral.ng/champagne-and-spa...  hampagne

# %% [markdown]
# ### Rename the column labels in other four dataframes

# %%
df_wine.rename(columns={'wine_name': 'product_name','wine_price':'product_price', 'wine_vol' : 'product_capacity',
                          'wine_product_link' : 'product_link'},inplace=True)

df_spirit.rename(columns={'spirit_name': 'product_name','spirit_price':'product_price', 'spirit_vol' : 'product_capacity',
                          'spirit_product_link' : 'product_link'},inplace=True)

df_champagne.rename(columns={'Champagne_name': 'product_name','Champagne_price':'product_price', 'Champagne_vol' : 'product_capacity',
                          'Champagne_product_link' : 'product_link'},inplace=True)

df_gift_idea.rename(columns={'gift_ideas_name': 'product_name','gift_ideas_price':'product_price', 'gift_ideas_vol' : 'product_capacity',
                          'gift_ideas_product_link' : 'product_link'},inplace=True)

# %% [markdown]
# ## combining all procuts into Master DataFrame

# %%
master_Data = pd.concat([df_wine, df_spirit,df_champagne, df_gift_idea], axis=0)

# %%
master_Data
# Out:
#                         product_name product_price product_capacity  \
# 0   B&G Cuvee Reserve Speciale Rose      ₦3,900.00             75cl
# 1            B&G Reserve Chardonnay      ₦5,200.00             75CL
# 2   Boekenhoutskloof Semillon White     ₦13,000.00             75cl
# 3                  Cheval Des Andes     ₦56,100.00             75cl
# 4         Clarendelle Bordeaux Rose      ₦8,200.00             75cl
# ..                               ...           ...              ...
# 33    Valentine's Gift Set for Her 1   ₦100,000.00              NaN
# 34    Valentine's Gift Set for Her 2    ₦60,000.00              NaN
# 35    Valentine's Gift Set for Him 1   ₦100,000.00              NaN
# 36    Valentine's Gift Set for Him 2    ₦60,000.00              NaN
# 37              Veuve Clicquot Brut     ₦50,420.00             75CL
#
#                                          product_link   category
# 0   https://www.cellarcentral.ng/wines?product_id=704       wine
# 1   https://www.cellarcentral.ng/wines/b-and-g-res...       wine
# 2   https://www.cellarcentral.ng/wines?product_id=563       wine
# 3   https://www.cellarcentral.ng/wines?product_id=495       wine
# 4   https://www.cellarcentral.ng/wines/clarendelle...       wine
# ..                                                ...        ...
# 33  https://www.cellarcentral.ng/special-offers?pr...  gift idea
# 34  https://www.cellarcentral.ng/special-offers?pr...  gift idea
# 35  https://www.cellarcentral.ng/special-offers?pr...  gift idea
# 36  https://www.cellarcentral.ng/special-offers?pr...  gift idea
# 37  https://www.cellarcentral.ng/special-offers/ve...  gift idea
#
# [228 rows x 5 columns]

# %%
master_Data.to_csv('CellarCentral website products data.csv', index = False)
